# %% [markdown]
# Tham khảo: https://codetudau.com/bag-of-words-tf-idf-xu-ly-ngon-ngu-tu-nhien/

# %%
docA = "the quick brown fox jumps over the lazy dog and"
docB = "never jump over the lazy dog quickly"

bowA = docA.split(" ")
bowB = docB.split(" ")

#Create dictionary
word_dict = set(bowA).union(set(bowB))

wordDictA = dict.fromkeys(word_dict, 0)
wordDictB = dict.fromkeys(word_dict, 0)
print(wordDictA)
print(wordDictB)
#count the word in bads
for word in bowA:
    wordDictA[word]+=1

for word in bowB:
    wordDictB[word]+=1
# Out:
# {'and': 0, 'lazy': 0, 'quick': 0, 'over': 0, 'jump': 0, 'fox': 0, 'the': 0, 'jumps': 0, 'brown': 0, 'dog': 0, 'never': 0, 'quickly': 0}
# {'and': 0, 'lazy': 0, 'quick': 0, 'over': 0, 'jump': 0, 'fox': 0, 'the': 0, 'jumps': 0, 'brown': 0, 'dog': 0, 'never': 0, 'quickly': 0}

# %%
print(wordDictA)
# Out:
# {'and': 1, 'lazy': 1, 'quick': 1, 'over': 1, 'jump': 0, 'fox': 1, 'the': 2, 'jumps': 1, 'brown': 1, 'dog': 1, 'never': 0, 'quickly': 0}

# %%
print(wordDictB)
# Out:
# {'and': 0, 'lazy': 1, 'quick': 0, 'over': 1, 'jump': 1, 'fox': 0, 'the': 1, 'jumps': 0, 'brown': 0, 'dog': 1, 'never': 1, 'quickly': 1}

# %%
#calculate TF
def compute_TF(word_dict, bow):
    tf_dict = {}
    bow_count = len(bow)
    for word, count in word_dict.items():
        tf_dict[word] = count/float(bow_count)
    
    return tf_dict    
    
tf_bowA = compute_TF(wordDictA, bowA)
tf_bowB = compute_TF(wordDictB, bowB)

# %%
print(tf_bowA)
# Out:
# {'and': 0.1, 'lazy': 0.1, 'quick': 0.1, 'over': 0.1, 'jump': 0.0, 'fox': 0.1, 'the': 0.2, 'jumps': 0.1, 'brown': 0.1, 'dog': 0.1, 'never': 0.0, 'quickly': 0.0}

# %%
print(tf_bowB)
# Out:
# {'and': 0.0, 'lazy': 0.14285714285714285, 'quick': 0.0, 'over': 0.14285714285714285, 'jump': 0.14285714285714285, 'fox': 0.0, 'the': 0.14285714285714285, 'jumps': 0.0, 'brown': 0.0, 'dog': 0.14285714285714285, 'never': 0.14285714285714285, 'quickly': 0.14285714285714285}

# %%
def compute_IDF(doc_list):
    import math
    idf_dict = {}
    N = len(doc_list)
    
    #count number of documents that contain this word
    idf_dict = dict.fromkeys(doc_list[0].keys(), 0)
    for doc in doc_list:
        for word, count in doc.items():
            if count > 0:
                idf_dict[word] += 1
                
    for word, count in idf_dict.items():
        idf_dict[word] = math.log(N/float(count))
        
    return idf_dict

# %%
idfs = compute_IDF([wordDictA, wordDictB])
print(idfs)
# Out:
# {'and': 0.6931471805599453, 'lazy': 0.0, 'quick': 0.6931471805599453, 'over': 0.0, 'jump': 0.6931471805599453, 'fox': 0.6931471805599453, 'the': 0.0, 'jumps': 0.6931471805599453, 'brown': 0.6931471805599453, 'dog': 0.0, 'never': 0.6931471805599453, 'quickly': 0.6931471805599453}

# %%
def compute_TFIDF(tf_bow, idfs):
    tfidf = {}
    for word, val in tf_bow.items():
        tfidf[word] = val*idfs[word]
    return tfidf

# %%
tfidf_bowA = compute_TFIDF(tf_bowA, idfs)
tfidf_bowB = compute_TFIDF(tf_bowB, idfs)

# %%
print(tfidf_bowA)
# Out:
# {'and': 0.06931471805599453, 'lazy': 0.0, 'quick': 0.06931471805599453, 'over': 0.0, 'jump': 0.0, 'fox': 0.06931471805599453, 'the': 0.0, 'jumps': 0.06931471805599453, 'brown': 0.06931471805599453, 'dog': 0.0, 'never': 0.0, 'quickly': 0.0}

# %%
print(tfidf_bowB)
# Out:
# {'and': 0.0, 'lazy': 0.0, 'quick': 0.0, 'over': 0.0, 'jump': 0.09902102579427789, 'fox': 0.0, 'the': 0.0, 'jumps': 0.0, 'brown': 0.0, 'dog': 0.0, 'never': 0.09902102579427789, 'quickly': 0.09902102579427789}

# %%
import pandas as pd   
df = pd.DataFrame([tfidf_bowA, tfidf_bowB])
print(df)
# Out:
#         and     brown  dog       fox      jump     jumps  lazy     never  \
# 0  0.069315  0.069315  0.0  0.069315  0.000000  0.069315   0.0  0.000000
# 1  0.000000  0.000000  0.0  0.000000  0.099021  0.000000   0.0  0.099021
#
#    over     quick   quickly  the
# 0   0.0  0.069315  0.000000  0.0
# 1   0.0  0.000000  0.099021  0.0
