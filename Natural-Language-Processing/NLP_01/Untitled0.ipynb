# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
example_text = "Hello there, how are you doing today? The weather is great and Python is awsome."

print(sent_tokenize(example_text))
# Out:
# ['Hello there, how are you doing today?', 'The weather is great and Python is awsome.']

# %%
print(word_tokenize(example_text))
# Out:
# ['Hello', 'there', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', 'and', 'Python', 'is', 'awsome', '.']

# %%
for i in word_tokenize(example_text):
  print(i)
# Out:
# Hello
# there
# ,
# how
# are
# you
# doing
# today
# ?
# The
# weather
# is
# great
# and
# Python
# is
# awsome
# .

# %% [markdown]
# **P2**

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
example_text1 = "this is example showing off stop word filtration"
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# {'yourselves', 'and', 'very', 'or', 'if', 'itself', "you'll", 'isn', 'up', 'any', 'being', 'at', 'hers', 'having', "haven't", 'to', 't', 'they', 'there', 'once', "doesn't", "weren't", 'as', "don't", 'an', 'so', 'will', "shouldn't", "you're", 'd', 'where', 'after', 'the', "that'll", 'she', 'mustn', 'with', 'off', "shan't", 'ours', 'you', "it's", 'are', 'do', 'these', 'our', 'because', "wasn't", 'not', 'did', 'aren', 'by', 'down', 'yours', "mightn't", 'should', "aren't", 'against', 'above', 'how', 'but', 'weren', 'we', "wouldn't", 'mightn', 'has', 'his', 'through', 'haven', 'same', 'during', 'few', 'each', 'such', 'its', 'until', 'when', 'more', 'himself', 'under', 'he', "needn't", 'won', "didn't", "you've", 're', "hadn't", 'out', 'than', 'does', 'that', 'been', 'who', 'below', 'again', 'yourself', 'm', 'too', 've', 'then', 'why', 'can', 'hasn', 'it', "should've", "isn't", 'most', 'of', 'shouldn', 'them', 'be', 'wasn', 'was', 'between', 'other', "she's", 'in', 'this', 'don', 'ourselves', 'had', 'just', 'your', "hasn't", 'no', 'needn', 'only', 'their', 'whom', 'over', 'shan', "couldn't", 'didn', 'wouldn', 'is', "won't", 'while', 'theirs', 'were', 'hadn', "you'd", 'own', "mustn't", 'into', 'y', 'about', 'o', 'which', 'my', 'ma', 'on', 'i', 'doing', 'now', 'him', 'for', 'from', 'all', 'couldn', 'herself', 'a', 'further', 'some', 'am', 'nor', 'have', 'doesn', 'themselves', 'me', 'those', 'll', 'both', 'her', 'myself', 'what', 's', 'here', 'ain', 'before'}

# %%
words = word_tokenize(example_text1)
filtered_sentence = []
for w in words:
  if w not in stop_words:
    filtered_sentence.append(w)
print(filtered_sentence)
# Out:
# ['example', 'showing', 'stop', 'word', 'filtration']
